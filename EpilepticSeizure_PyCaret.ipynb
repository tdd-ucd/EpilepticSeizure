# %%
# pip install pycaret

# %%
# check pycaret version
import pycaret
print('PyCaret: %s' % pycaret.__version__)
# Out:
# PyCaret: 2.2.0

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# define the location of the dataset
file='data.csv'
# load the dataset
df = pd.read_csv(file)
# summarize the shape of the dataset
print(df.shape)
# Out:
# (11500, 180)

# %%
# summarize the first few rows of data
print(df.head())
# Out:
#    Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
# compare machine learning algorithms on the epileptic seizure dataset
#from pandas import read_csv
from pycaret.classification import setup
from pycaret.classification import compare_models

# define the location of the dataset
#file='data.csv'
# load the dataset
#df = pd.read_csv(file)

# setup the dataset
grid = setup(data=df, target=df.columns[-1], html=False, silent=True, verbose=False)
# evaluate models and compare models
best = compare_models()
# report the best model
print(best)
# Out:
#                   Model  Accuracy     AUC  Recall   Prec.      F1  Kappa  \
# lr  Logistic Regression    0.2451  0.5277  0.2449  0.2505  0.2458  0.056
#
#        MCC  TT (Sec)
# lr  0.0562    70.456
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# knn  K Neighbors Classifier    0.4505  0.7406  0.4497  0.5535  0.4384  0.3123
# lr      Logistic Regression    0.2451  0.5277  0.2449  0.2505  0.2458  0.0560
#
#         MCC  TT (Sec)
# knn  0.3340    37.672
# lr   0.0562    70.456
#                       Model  Accuracy     AUC  Recall   Prec.      F1   Kappa  \
# knn  K Neighbors Classifier    0.4505  0.7406  0.4497  0.5535  0.4384  0.3123
# nb              Naive Bayes    0.3655  0.7348  0.3706  0.3329  0.2571  0.2114
# lr      Logistic Regression    0.2451  0.5277  0.2449  0.2505  0.2458  0.0560
#
#         MCC  TT (Sec)
# knn  0.3340    37.672
# nb   0.3414     0.805
# lr   0.0562    70.456
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# dt   Decision Tree Classifier    0.4620  0.6636  0.4622  0.4696  0.4652
# knn    K Neighbors Classifier    0.4505  0.7406  0.4497  0.5535  0.4384
# nb                Naive Bayes    0.3655  0.7348  0.3706  0.3329  0.2571
# lr        Logistic Regression    0.2451  0.5277  0.2449  0.2505  0.2458
#
#       Kappa     MCC  TT (Sec)
# dt   0.3274  0.3277     1.203
# knn  0.3123  0.3340    37.672
# nb   0.2114  0.3414     0.805
# lr   0.0560  0.0562    70.456
#                         Model  Accuracy     AUC  Recall   Prec.      F1  \
# dt   Decision Tree Classifier    0.4620  0.6636  0.4622  0.4696  0.4652
# knn    K Neighbors Classifier    0.4505  0.7406  0.4497  0.5535  0.4384
# nb                Naive Bayes    0.3655  0.7348  0.3706  0.3329  0.2571
# lr        Logistic Regression    0.2451  0.5277  0.2449  0.2505  0.2458
# svm       SVM - Linear Kernel    0.2014  0.0000  0.2014  0.2023  0.1979
#
#       Kappa     MCC  TT (Sec)
# dt   0.3274  0.3277     1.203
# knn  0.3123  0.3340    37.672
# nb   0.2114  0.3414     0.805
# lr   0.0560  0.0562    70.456
# svm  0.0018  0.0018    12.010
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# dt     Decision Tree Classifier    0.4620  0.6636  0.4622  0.4696  0.4652
# knn      K Neighbors Classifier    0.4505  0.7406  0.4497  0.5535  0.4384
# nb                  Naive Bayes    0.3655  0.7348  0.3706  0.3329  0.2571
# lr          Logistic Regression    0.2451  0.5277  0.2449  0.2505  0.2458
# ridge          Ridge Classifier    0.2204  0.0000  0.2203  0.2187  0.1942
# svm         SVM - Linear Kernel    0.2014  0.0000  0.2014  0.2023  0.1979
#
#         Kappa     MCC  TT (Sec)
# dt     0.3274  0.3277     1.203
# knn    0.3123  0.3340    37.672
# nb     0.2114  0.3414     0.805
# lr     0.0560  0.0562    70.456
# ridge  0.0255  0.0269    55.621
# svm    0.0018  0.0018    12.010
#                           Model  Accuracy     AUC  Recall   Prec.      F1  \
# rf     Random Forest Classifier    0.6539  0.8912  0.6543  0.6522  0.6496
# dt     Decision Tree Classifier    0.4620  0.6636  0.4622  0.4696  0.4652
# knn      K Neighbors Classifier    0.4505  0.7406  0.4497  0.5535  0.4384
# nb                  Naive Bayes    0.3655  0.7348  0.3706  0.3329  0.2571
# lr          Logistic Regression    0.2451  0.5277  0.2449  0.2505  0.2458
# ridge          Ridge Classifier    0.2204  0.0000  0.2203  0.2187  0.1942
# svm         SVM - Linear Kernel    0.2014  0.0000  0.2014  0.2023  0.1979
#
#         Kappa     MCC  TT (Sec)
# rf     0.5673  0.5690     2.563
# dt     0.3274  0.3277     1.203
# knn    0.3123  0.3340    37.672
# nb     0.2114  0.3414     0.805
# lr     0.0560  0.0562    70.456
# ridge  0.0255  0.0269    55.621
# svm    0.0018  0.0018    12.010
#                                  Model  Accuracy     AUC  Recall   Prec.  \
# rf            Random Forest Classifier    0.6539  0.8912  0.6543  0.6522
gradient Boosting Classifier    0.5611  0.8442  0.5618  0.5674
# dt              Decision Tree Classifier    0.4620  0.6636  0.4622  0.4696
# knn               K Neighbors Classifier    0.4505  0.7406  0.4497  0.5535
# ada                 Ada Boost Classifier    0.4391  0.6691  0.4371  0.4296
# nb                           Naive Bayes    0.3655  0.7348  0.3706  0.3329
# lr                   Logistic Regression    0.2451  0.5277  0.2449  0.2505
# qda      Quadratic Discriminant Analysis    0.2372  0.5232  0.2373  0.2293
# ridge                   Ridge Classifier    0.2204  0.0000  0.2203  0.2187
# svm                  SVM - Linear Kernel    0.2014  0.0000  0.2014  0.2023
# lda         Linear Discriminant Analysis    0.0804  0.1610  0.0802  0.0826
# xgboost        Extreme Gradient Boosting    0.0000  0.0000  0.0000  0.0000
#
#              F1   Kappa     MCC  TT (Sec)
# et       0.6547  0.5699  0.5722     5.110
# rf       0.6496  0.5673  0.5690     2.563
# gbc      0.5570  0.4512  0.4556    82.572
# dt       0.4652  0.3274  0.3277     1.203
# knn      0.4384  0.3123  0.3340    37.672
# ada      0.3876  0.2979  0.3294     4.410
# nb       0.2571  0.2114  0.3414     0.805
# lr       0.2458  0.0560  0.0562    70.456
# qda      0.2107  0.0465  0.0492    10.530
# ridge    0.1942  0.0255  0.0269    55.621
# svm      0.1979  0.0018  0.0018    12.010
# lda      0.0772  0.0253  0.0258   163.469
# xgboost  0.0000  0.0000  0.0000     0.482
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.6749  0.9092  0.6752  0.6787
# et                 Extra Trees Classifier    0.6560  0.8895  0.6560  0.6620
# rf               Random Forest Classifier    0.6539  0.8912  0.6543  0.6522
# gbc          Gradient Boosting Classifier    0.5611  0.8442  0.5618  0.5674
# dt               Decision Tree Classifier    0.4620  0.6636  0.4622  0.4696
# knn                K Neighbors Classifier    0.4505  0.7406  0.4497  0.5535
# ada                  Ada Boost Classifier    0.4391  0.6691  0.4371  0.4296
# nb                            Naive Bayes    0.3655  0.7348  0.3706  0.3329
# lr                    Logistic Regression    0.2451  0.5277  0.2449  0.2505
# qda       Quadratic Discriminant Analysis    0.2372  0.5232  0.2373  0.2293
# ridge                    Ridge Classifier    0.2204  0.0000  0.2203  0.2187
# svm                   SVM - Linear Kernel    0.2014  0.0000  0.2014  0.2023
# lda          Linear Discriminant Analysis    0.0804  0.1610  0.0802  0.0826
# xgboost         Extreme Gradient Boosting    0.0000  0.0000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.6757  0.5935  0.5940     5.100
# et        0.6547  0.5699  0.5722     5.110
# rf        0.6496  0.5673  0.5690     2.563
# gbc       0.5570  0.4512  0.4556    82.572
# dt        0.4652  0.3274  0.3277     1.203
# knn       0.4384  0.3123  0.3340    37.672
# ada       0.3876  0.2979  0.3294     4.410
# nb        0.2571  0.2114  0.3414     0.805
# lr        0.2458  0.0560  0.0562    70.456
# qda       0.2107  0.0465  0.0492    10.530
# ridge     0.1942  0.0255  0.0269    55.621
# svm       0.1979  0.0018  0.0018    12.010
# lda       0.0772  0.0253  0.0258   163.469
# xgboost   0.0000  0.0000  0.0000     0.482
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.6749  0.9092  0.6752  0.6787
# catboost              CatBoost Classifier    0.6576  0.9032  0.6580  0.6575
# et                 Extra Trees Classifier    0.6560  0.8895  0.6560  0.6620
# rf               Random Forest Classifier    0.6539  0.8912  0.6543  0.6522
# gbc          Gradient Boosting Classifier    0.5611  0.8442  0.5618  0.5674
# dt               Decision Tree Classifier    0.4620  0.6636  0.4622  0.4696
# knn                K Neighbors Classifier    0.4505  0.7406  0.4497  0.5535
# ada                  Ada Boost Classifier    0.4391  0.6691  0.4371  0.4296
# nb                            Naive Bayes    0.3655  0.7348  0.3706  0.3329
# lr                    Logistic Regression    0.2451  0.5277  0.2449  0.2505
# qda       Quadratic Discriminant Analysis    0.2372  0.5232  0.2373  0.2293
# ridge                    Ridge Classifier    0.2204  0.0000  0.2203  0.2187
# svm                   SVM - Linear Kernel    0.2014  0.0000  0.2014  0.2023
# lda          Linear Discriminant Analysis    0.0804  0.1610  0.0802  0.0826
# xgboost         Extreme Gradient Boosting    0.0000  0.0000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.6757  0.5935  0.5940     5.100
# catboost  0.6560  0.5719  0.5727    58.303
# et        0.6547  0.5699  0.5722     5.110
# rf        0.6496  0.5673  0.5690     2.563
# gbc       0.5570  0.4512  0.4556    82.572
# dt        0.4652  0.3274  0.3277     1.203
# knn       0.4384  0.3123  0.3340    37.672
# ada       0.3876  0.2979  0.3294     4.410
# nb        0.2571  0.2114  0.3414     0.805
# lr        0.2458  0.0560  0.0562    70.456
# qda       0.2107  0.0465  0.0492    10.530
# ridge     0.1942  0.0255  0.0269    55.621
# svm       0.1979  0.0018  0.0018    12.010
# lda       0.0772  0.0253  0.0258   163.469
# xgboost   0.0000  0.0000  0.0000     0.482
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# lightgbm  Light Gradient Boosting Machine    0.6749  0.9092  0.6752  0.6787
# catboost              CatBoost Classifier    0.6576  0.9032  0.6580  0.6575
# et                 Extra Trees Classifier    0.6560  0.8895  0.6560  0.6620
# rf               Random Forest Classifier    0.6539  0.8912  0.6543  0.6522
# gbc          Gradient Boosting Classifier    0.5611  0.8442  0.5618  0.5674
# dt               Decision Tree Classifier    0.4620  0.6636  0.4622  0.4696
# knn                K Neighbors Classifier    0.4505  0.7406  0.4497  0.5535
# ada                  Ada Boost Classifier    0.4391  0.6691  0.4371  0.4296
# nb                            Naive Bayes    0.3655  0.7348  0.3706  0.3329
# lr                    Logistic Regression    0.2451  0.5277  0.2449  0.2505
# qda       Quadratic Discriminant Analysis    0.2372  0.5232  0.2373  0.2293
# ridge                    Ridge Classifier    0.2204  0.0000  0.2203  0.2187
# svm                   SVM - Linear Kernel    0.2014  0.0000  0.2014  0.2023
# lda          Linear Discriminant Analysis    0.0804  0.1610  0.0802  0.0826
# xgboost         Extreme Gradient Boosting    0.0000  0.0000  0.0000  0.0000
#
#               F1   Kappa     MCC  TT (Sec)
# lightgbm  0.6757  0.5935  0.5940     5.100
# catboost  0.6560  0.5719  0.5727    58.303
# et        0.6547  0.5699  0.5722     5.110
# rf        0.6496  0.5673  0.5690     2.563
# gbc       0.5570  0.4512  0.4556    82.572
# dt        0.4652  0.3274  0.3277     1.203
# knn       0.4384  0.3123  0.3340    37.672
# ada       0.3876  0.2979  0.3294     4.410
# nb        0.2571  0.2114  0.3414     0.805
# lr        0.2458  0.0560  0.0562    70.456
# qda       0.2107  0.0465  0.0492    10.530
# ridge     0.1942  0.0255  0.0269    55.621
# svm       0.1979  0.0018  0.0018    12.010
# lda       0.0772  0.0253  0.0258   163.469
# xgboost   0.0000  0.0000  0.0000     0.482
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=2253, reg_alpha=0.0, reg_lambda=0.0, silent=True,
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
# tune model hyperparameters on the sonar classification dataset
#from pandas import read_csv
from sklearn.ensemble import ExtraTreesClassifier
#from pycaret.classification import setup
from pycaret.classification import tune_model

# define the location of the dataset
#file='data.csv'
# load the dataset
#df = pd.read_csv(file)

# setup the dataset
grid = setup(data=df, target=df.columns[-1], html=False, silent=True, verbose=False)
# tune model hyperparameters
best = tune_model(ExtraTreesClassifier(), n_iter=200, choose_better=True)
# report the best model
print(best)
# Out:
# Fitting 10 folds for each of 200 candidates, totalling 2000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   22.9s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed: 23.2min
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed: 36.2min
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed: 157.7min
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed: 271.2min
# [Parallel(n_jobs=-1)]: Done 2000 out of 2000 | elapsed: 316.5min finished
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# 0       0.5429  0.8327  0.5434  0.6147  0.5174  0.4291  0.4684
# 1       0.5727  0.8310  0.5728  0.6304  0.5457  0.4662  0.4997
# 2       0.5453  0.8344  0.5453  0.5999  0.5106  0.4321  0.4732
# 3       0.5478  0.8255  0.5479  0.5831  0.5136  0.4353  0.4706
# 4       0.5540  0.8383  0.5537  0.6287  0.5224  0.4426  0.4798
# 5       0.5602  0.8390  0.5596  0.6374  0.5337  0.4504  0.4885
# 6       0.5466  0.8327  0.5460  0.6197  0.5152  0.4333  0.4756
# 7       0.5416  0.8345  0.5410  0.6209  0.5149  0.4271  0.4645
# 8       0.5478  0.8243  0.5483  0.6129  0.5206  0.4350  0.4734
# 9       0.5386  0.8310  0.5394  0.5955  0.5100  0.4237  0.4594
# Mean    0.5498  0.8323  0.5497  0.6143  0.5204  0.4375  0.4753
# SD      0.0096  0.0045  0.0095  0.0161  0.0107  0.0120  0.0111
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)
